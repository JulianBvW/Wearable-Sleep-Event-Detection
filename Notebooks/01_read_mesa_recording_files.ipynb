# %% [markdown]
# ### Setup

# %%
import pyedflib
import pandas as pd
from lxml import etree

# %% [markdown]
# ### Functions

# %%
### EDF Files

def load_psg(path):
    edf_reader = pyedflib.EdfReader(path)

    signal_labels = edf_reader.getSignalLabels()

    signals = {}
    frequencies = {}
    for i in range(edf_reader.signals_in_file):
        signals[signal_labels[i]] = pd.Series(edf_reader.readSignal(i))
        frequencies[signal_labels[i]] = edf_reader.getSampleFrequency(i)
    
    edf_reader.close()
    return signals, frequencies

### R-Point CSV Files

def load_rpoint(path):
    df = pd.read_csv(path)
    return df

### NSRR Annotation Files

def to_obj(event):
    obj = {}
    for child in event:
        #if not child.tag == 'EventType':
            obj[child.tag] = child.text
    return obj

def load_annotations(path):
    tree = etree.parse(path)
    root = tree.getroot()
    all_events = root.xpath("//ScoredEvent")

    recording_start = []
    events_respiratory = []
    events_arousals = []
    events_limb_movements = []
    events_stages = []

    event_categories = {
        None: recording_start,
        'Respiratory|Respiratory': events_respiratory,
        'Arousals|Arousals': events_arousals,
        'Limb Movement|Limb Movement': events_limb_movements,
        'Stages|Stages': events_stages,
        'Technician Notes': [], # TODO what is this?
        'Electrocardiogram|Electrocardiogram': [] # TODO again
    }

    for event in all_events:
        for child in event:
            if child.tag == 'EventType':
                event_categories[child.text].append(to_obj(event))
    
    recording_start = recording_start[0]['ClockTime']
    return recording_start, \
        events_respiratory, \
        events_arousals, \
        pd.DataFrame(events_limb_movements), \
        events_stages

# %% [markdown]
# ### Data

# %%
MAIN_DIR = '/vol/sleepstudy/datasets/mesa/polysomnography/'

# %% [markdown]
# PSG

# %%
mesa0001_psg, mesa0001_psg_freqs = load_psg(MAIN_DIR + 'edfs/mesa-sleep-0001.edf')
print(list(mesa0001_psg.keys()))
mesa0001_psg['EKG'].plot(figsize=(20, 3))
# Out:
# ['EKG', 'EOG-L', 'EOG-R', 'EMG', 'EEG1', 'EEG2', 'EEG3', 'Pres', 'Flow', 'Snore', 'Thor', 'Abdo', 'Leg', 'Therm', 'Pos', 'EKG_Off', 'EOG-L_Off', 'EOG-R_Off', 'EMG_Off', 'EEG1_Off', 'EEG2_Off', 'EEG3_Off', 'Pleth', 'OxStatus', 'SpO2', 'HR', 'DHR']
# <Axes: >

# %%
df_signals, df_frequencies, df_num_vals = [], [], []
for signal in list(mesa0001_psg.keys()):
    df_signals.append(signal)
    df_frequencies.append(mesa0001_psg_freqs[signal])
    df_num_vals.append(len(mesa0001_psg[signal]))
df = pd.DataFrame({'Signal': df_signals, 'Frequency': df_frequencies, '# Values': df_num_vals})
df.set_index('Signal')
# Out:
#            Frequency  # Values
# Signal
# EKG            256.0  11058944
# EOG-L          256.0  11058944
# EOG-R          256.0  11058944
# EMG            256.0  11058944
# EEG1           256.0  11058944
# EEG2           256.0  11058944
# EEG3           256.0  11058944
# Pres            32.0   1382368
# Flow            32.0   1382368
# Snore           32.0   1382368
# Thor            32.0   1382368
# Abdo            32.0   1382368
# Leg             32.0   1382368
# Therm           32.0   1382368
# Pos             32.0   1382368
# EKG_Off          1.0     43199
# EOG-L_Off        1.0     43199
# EOG-R_Off        1.0     43199
# EMG_Off          1.0     43199
# EEG1_Off         1.0     43199
# EEG2_Off         1.0     43199
# EEG3_Off         1.0     43199
# Pleth          256.0  11058944
# OxStatus         1.0     43199
# SpO2             1.0     43199
# HR               1.0     43199
# DHR            256.0  11058944

# %% [markdown]
# R-Points

# %%
mesa0001_rpoints = load_rpoint(MAIN_DIR + 'annotations-rpoints/mesa-sleep-0001-rpoint.csv')
mesa0001_rpoints.head()
# Out:
#    epoch  RPoint  Start  End  STLevel1  STSlope1  STLevel2  STSlope2  Manual  \
# 0      1     149    144  155       220     -1292      9866         0       0
# 1      1     332    325  346       214      1998       346         0       0
# 2      1     533    502  546      -931      1783       546         0       0
# 3      1     733    723  746        24      1077       746         0       0
# 4      1     930    920  937       216      -865       937         0       0
#
#    Type  Class  PPoint  PStart  PEnd  TPoint  TStart  TEnd  TemplateID  \
# 0     1    NaN     NaN     NaN   NaN     215     NaN   NaN           0
# 1     1    NaN     NaN     NaN   NaN     393     NaN   NaN           0
# 2     1    NaN     NaN     NaN   NaN     595     NaN   NaN           0
# 3     1    NaN     NaN     NaN   NaN     793     NaN   NaN           0
# 4     1    NaN     NaN     NaN   NaN     990     NaN   NaN           0
#
#     seconds  stage
# 0  0.582031      0
# 1  1.296875      0
# 2  2.082031      0
# 3  2.863281      0
# 4  3.632812      0

# %% [markdown]
# NSRR Annotations

# %%
start, er, ea, el, stages = load_annotations(MAIN_DIR + 'annotations-events-nsrr/mesa-sleep-0001-nsrr.xml')

stage_list = []
for _, state_event in stages.iterrows():
    stage = int(state_event.loc['EventConcept'].split('|')[1])
    stage_list += [stage]*int(state_event.loc['Duration'].split('.')[0])
pd.Series(stage_list).plot(figsize=(20, 3))
# Out:
# <Axes: >

# %%
stages
# Out:
# [{'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '0.0',
#   'Duration': '5190.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5190.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '5220.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5310.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5370.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5460.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5490.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5580.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5670.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '5730.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5760.0',
#   'Duration': '240.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '6000.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '6030.0',
#   'Duration': '690.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '6720.0',
#   'Duration': '2700.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9420.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '9450.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '9600.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9630.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '9660.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9990.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10020.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '10350.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10380.0',
#   'Duration': '270.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10650.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '10710.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10740.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10890.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10980.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11010.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11040.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11070.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11100.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11130.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11160.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11280.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11370.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11430.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11460.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11490.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11550.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11580.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11610.0',
#   'Duration': '240.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11850.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11880.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11970.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12000.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12090.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12150.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12240.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12300.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12330.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12480.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12510.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '12600.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12810.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '12840.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12870.0',
#   'Duration': '900.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13770.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '13830.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13860.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '13890.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13920.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '13950.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '14010.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '14160.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start':
0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33030.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33150.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33180.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33210.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33300.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33360.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33480.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33510.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33540.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33750.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33810.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '33840.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33870.0',
#   'Duration': '180.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34050.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34140.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34170.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34260.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34290.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34320.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34350.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34410.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34440.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34470.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34500.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34530.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34560.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34680.0',
#   'Duration': '2070.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '36750.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '36870.0',
#   'Duration': '1140.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '38010.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '38160.0',
#   'Duration': '5010.0'}]

# %%
_, _, _, _, stages = load_annotations(MAIN_DIR + 'annotations-events-nsrr/mesa-sleep-0001-nsrr.xml')
all_keys = []
for event in stages:
    all_keys += list(event.keys())
print(Counter(all_keys))
# Out:
# Counter({'EventType': 259, 'EventConcept': 259, 'Start': 259, 'Duration': 259})

# %%
stages
# Out:
# [{'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '0.0',
#   'Duration': '5190.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5190.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '5220.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5310.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5370.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5460.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5490.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '5580.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5670.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '5730.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '5760.0',
#   'Duration': '240.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '6000.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '6030.0',
#   'Duration': '690.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '6720.0',
#   'Duration': '2700.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9420.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '9450.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '9600.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9630.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '9660.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '9990.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10020.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '10350.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10380.0',
#   'Duration': '270.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10650.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '10710.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10740.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '10890.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '10980.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11010.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11040.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11070.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11100.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11130.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11160.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11280.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11370.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11430.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11460.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11490.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11550.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '11580.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11610.0',
#   'Duration': '240.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11850.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '11880.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '11970.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12000.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12090.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12150.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12240.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12300.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12330.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '12480.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '12510.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '12600.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12810.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '12840.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '12870.0',
#   'Duration': '900.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13770.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '13830.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13860.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '13890.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '13920.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '13950.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '14010.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '14160.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '14190.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '14220.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '14340.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '14400.0',
#   'Duration': '390.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '14790.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '14910.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '14970.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '15090.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '15120.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '15240.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '15270.0',
#   'Duration': '390.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '15660.0',
#   'Duration': '240.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '15900.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '15960.0',
#   'Duration': '180.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '16140.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '16170.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '16500.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '16560.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '16650.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '16680.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '16740.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '16770.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '16800.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '16830.0',
#   'Duration': '390.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '17220.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '17250.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '17310.0',
#   'Duration': '930.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '18240.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '18270.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '18330.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '18480.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '18540.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '18570.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '18630.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '18660.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '18690.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '18810.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '18840.0',
#   'Duration': '540.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '19380.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '19440.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '19500.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '19560.0',
#   'Duration': '2220.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '21780.0',
#   'Duration': '180.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '21960.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '22170.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '22230.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '22260.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '22290.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '22320.0',
#   'Duration': '180.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '22500.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '22530.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '22650.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '22680.0',
#   'Duration': '720.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '23400.0',
#   'Duration': '270.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '23670.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '23700.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '23760.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '23790.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '23880.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '23940.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '23970.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24000.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24030.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24060.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24090.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24180.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24240.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24300.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24360.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24450.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '24510.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24600.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '24630.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '24960.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '25170.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '25200.0',
#   'Duration': '720.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '25920.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '25950.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '25980.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26100.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26160.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26220.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26250.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26280.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26340.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26490.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26520.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26550.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26580.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26610.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '26670.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26760.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26850.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '26880.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26910.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '26940.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '26970.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '27060.0',
#   'Duration': '660.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '27720.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '27750.0',
#   'Duration': '270.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '28020.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '28050.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '28080.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '28110.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '28440.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '28470.0',
#   'Duration': '900.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29370.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '29430.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29550.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '29580.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29640.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '29760.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29790.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '29820.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29850.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '29910.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 3 sleep|3',
#   'Start': '29970.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '30120.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '30150.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '30180.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '30210.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '30240.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '30330.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '30480.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '30510.0',
#   'Duration': '330.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '30840.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31050.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31080.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '31110.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31230.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31260.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '31290.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31320.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31350.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '31380.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31410.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '31470.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '31590.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31650.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31680.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31740.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31770.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '31800.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '31860.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '31890.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '31980.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32010.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32040.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32130.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32160.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32370.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32400.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32430.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32490.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '32580.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32610.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32670.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '32700.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32730.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32760.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32820.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '32880.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '32940.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33030.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33150.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33180.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33210.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33300.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33360.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33480.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33510.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33540.0',
#   'Duration': '210.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33750.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '33810.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '33840.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '33870.0',
#   'Duration': '180.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34050.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34140.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34170.0',
#   'Duration': '90.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34260.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34290.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34320.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34350.0',
#   'Duration': '60.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34410.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '34440.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34470.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34500.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34530.0',
#   'Duration': '30.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '34560.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '34680.0',
#   'Duration': '2070.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 1 sleep|1',
#   'Start': '36750.0',
#   'Duration': '120.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Stage 2 sleep|2',
#   'Start': '36870.0',
#   'Duration': '1140.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'REM sleep|5',
#   'Start': '38010.0',
#   'Duration': '150.0'},
#  {'EventType': 'Stages|Stages',
#   'EventConcept': 'Wake|0',
#   'Start': '38160.0',
#   'Duration': '5010.0'}]

# %%
all_keys = []
all_EvTy = []
all_EvCo = []
all_Sta = []
all_Dur = []
all_Loc = []
for event in ea:
    all_keys += list(event.keys())
    all_EvTy.append(event['EventType'])
    all_EvCo.append(event['EventConcept'])
    all_keys += list(event.keys())
print(Counter(all_keys))
# Out:
# Counter({'EventType': 649, 'EventConcept': 649, 'Start': 649, 'Duration': 649, 'SignalLocation': 649, 'SpO2Nadir': 371, 'SpO2Baseline': 371})

# %%
print(', '.join(list(mesa0001_psg.keys())))
print(len(mesa0001_psg.keys()))
# Out:
# EKG, EOG-L, EOG-R, EMG, EEG1, EEG2, EEG3, Pres, Flow, Snore, Thor, Abdo, Leg, Therm, Pos, EKG_Off, EOG-L_Off, EOG-R_Off, EMG_Off, EEG1_Off, EEG2_Off, EEG3_Off, Pleth, OxStatus, SpO2, HR, DHR
# 27

# %%
all_keys = []
for ev in er:
    all_keys += list(ev.keys())
print(all_keys)
# Out:
# ['EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'EventConcept', 'Start', 'Duration', 'SignalLocation', 'SpO2Nadir', 'SpO2Baseline', 'Even ...

# %%
from collections import Counter
Counter(all_keys)
# Out:
# Counter({'EventConcept': 649,
#          'Start': 649,
#          'Duration': 649,
#          'SignalLocation': 649,
#          'SpO2Nadir': 371,
#          'SpO2Baseline': 371})

# %%
er[0]
# Out:
# {'EventConcept': 'SpO2 desaturation|SpO2 desaturation',
#  'Start': '148',
#  'Duration': '31',
#  'SignalLocation': 'SpO2',
#  'SpO2Nadir': '96',
#  'SpO2Baseline': '98.0'}

# %%
all_concepts = []
for ev in er:
    all_concepts.append(ev['EventConcept'])
Counter(all_concepts)
# Out:
# Counter({'SpO2 desaturation|SpO2 desaturation': 371,
#          'Unsure|Unsure': 157,
#          'Hypopnea|Hypopnea': 85,
#          'Obstructive apnea|Obstructive Apnea': 19,
#          'SpO2 artifact|SpO2 artifact': 17})

# %%
_, er2, ea2, _, _ = load_annotations(MAIN_DIR + 'annotations-events-nsrr/mesa-sleep-0010-nsrr.xml')

all_keys_er2 = []
for ev in er2:
    all_keys_er2 += list(ev.keys())
print('Keys er:', Counter(all_keys_er2))

all_keys_ea2 = []
for ev in ea2:
    all_keys_ea2 += list(ev.keys())
print('Keys ea:', Counter(all_keys_ea2))

all_concepts_er2 = []
for ev in er2:
    all_concepts_er2.append(ev['EventConcept'])
print('Concepts er:', Counter(all_concepts_er2))

all_concepts_ea2 = []
for ev in ea2:
    all_concepts_ea2.append(ev['EventConcept'])
print('Concepts er:', Counter(all_concepts_ea2))
# Out:
# Keys er: Counter({'EventConcept': 323, 'Start': 323, 'Duration': 323, 'SignalLocation': 323, 'SpO2Nadir': 201, 'SpO2Baseline': 201})
# Keys ea: Counter({'EventConcept': 97, 'Start': 97, 'Duration': 97, 'SignalLocation': 97})
# Concepts er: Counter({'SpO2 desaturation|SpO2 desaturation': 201, 'Hypopnea|Hypopnea': 60, 'Unsure|Unsure': 41, 'Obstructive apnea|Obstructive Apnea': 11, 'SpO2 artifact|SpO2 artifact': 10})
# Concepts er: Counter({'Arousal|Arousal ()': 97})

# %%
import os
from tqdm import tqdm

# %%
all_annots = os.listdir('/vol/sleepstudy/datasets/mesa/polysomnography/annotations-events-nsrr/')
all_concepts_annot = []
for annot in tqdm(all_annots):
    _, er, _, _, _ = load_annotations(MAIN_DIR + f'annotations-events-nsrr/{annot}')
    for ev in er2:
        all_concepts_annot.append(ev['EventConcept'])

Counter(all_concepts_annot)
# Out:
#   5%|▌         | 111/2056 [00:01<00:22, 87.59it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5041.8', 'Duration': '17.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5145.7', 'Duration': '4.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5239.8', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5273.3', 'Duration': '6.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5325.6', 'Duration': '19.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5734.6', 'Duration': '5.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5826.4', 'Duration': '7.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5851.7', 'Duration': '5.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5991.1', 'Duration': '8.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6012.3', 'Duration': '8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6046', 'Duration': '13.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6472', 'Duration': '8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6532.4', 'Duration': '20.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6581.3', 'Duration': '18.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10096.4', 'Duration': '28.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10155.8', 'Duration': '11.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10280.5', 'Duration': '9.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10304.5', 'Duration': '7.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10324.2', 'Duration': '25.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10456.9', 'Duration': '13.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10578.3', 'Duration': '21.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10669.7', 'Duration': '9.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10744.1', 'Duration': '18.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10822.6', 'Duration': '7.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10843.1', 'Duration': '7.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11495.7', 'Duration': '11.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11565.3', 'Duration': '22.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11647.8', 'Duration': '8.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician  ...
#  29%|██▊       | 586/2056 [00:06<00:18, 81.18it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5401.7', 'Duration': '16.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5456.5', 'Duration': '5.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5481', 'Duration': '5.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5506.5', 'Duration': '5.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5540.6', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5568.6', 'Duration': '8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5647', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5707.9', 'Duration': '7.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '8783', 'Duration': '7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13782.9', 'Duration': '13', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13961.7', 'Duration': '7.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13982', 'Duration': '5.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '16975.1', 'Duration': '14.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '17058.1', 'Duration': '14.3', 'Notes': 'Arousal (ARO Limb)'}]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25753.4', 'Duration': '7.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25787.8', 'Duration': '9.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25876', 'Duration': '25.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25920', 'Duration': '12.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25945.9', 'Duration': '6.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26001.2', 'Duration': '16.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26037.9', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26074.3', 'Duration': '11.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26155', 'Duration': '5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26260.7', 'Duration': '10.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26298.9', 'Duration': '12', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26334.8', 'Duration': '11.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26362.3', 'Duration': '7.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26444.2', 'Duration': '5.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '26680', 'Duration': '4.6', 'Notes': 'Arousal (ARO Limb)'}]
#  31%|███▏      | 644/2056 [00:07<00:16, 84.20it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '33201.9', 'Duration': '0', 'Notes': 'Arousal (ARO Limb)'}]
#  40%|███▉      | 819/2056 [00:09<00:14, 87.56it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '2950.3', 'Duration': '11.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '2994.2', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3044.7', 'Duration': '10.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3065.6', 'Duration': '13.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3104.1', 'Duration': '15.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3175.8', 'Duration': '4.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3225.8', 'Duration': '13', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3258.4', 'Duration': '6.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3279.8', 'Duration': '10.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3317.7', 'Duration': '6.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3417.6', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3467.2', 'Duration': '12.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3500.4', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3616.4', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3696', 'Duration': '5.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3828', 'Duration': '4.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3873.4', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3895.3', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3951', 'Duration': '8.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3984.9', 'Duration': '5.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4009.2', 'Duration': '5.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4033.2', 'Duration': '5.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4057.6', 'Duration': '5.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4082.8', 'Duration': '4.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4147.7', 'Duration': '0.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4147.9', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4168.5', 'Duration': '0', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4168.5', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4222', 'Durati ...
#  56%|█████▌    | 1153/2056 [00:13<00:09, 95.46it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4324.7', 'Duration': '6.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4351.3', 'Duration': '21.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4457.2', 'Duration': '18.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4653.7', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4707.4', 'Duration': '7.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4764.5', 'Duration': '3.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4973.8', 'Duration': '22.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5576.1', 'Duration': '7.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '8940.3', 'Duration': '25.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9018.9', 'Duration': '5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9082.5', 'Duration': '21.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9415.2', 'Duration': '19.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9640.2', 'Duration': '19.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9724.6', 'Duration': '4.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9740.5', 'Duration': '11.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9829.7', 'Duration': '26.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11677.7', 'Duration': '23.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13819.6', 'Duration': '26.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13938.9', 'Duration': '9.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14503.2', 'Duration': '16.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14623.2', 'Duration': '6.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15081.8', 'Duration': '4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15309.8', 'Duration': '4.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15362.2', 'Duration': '4.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15641.9', 'Duration': '5.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15945.1', 'Duration': '15.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '16344.6', 'Duration': '11.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '16495.8', 'Duration': '7.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Techni ...
#  72%|███████▏  | 1471/2056 [00:16<00:06, 93.29it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '1712.2', 'Duration': '5.1', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '1728.9', 'Duration': '5.7', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4233.1', 'Duration': '7.5', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4269.7', 'Duration': '19.7', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4866.2', 'Duration': '19.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4965.7', 'Duration': '9.6', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5339', 'Duration': '17.8', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5545', 'Duration': '7.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5924.6', 'Duration': '11', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5970.1', 'Duration': '22.2', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6057.9', 'Duration': '17.8', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6099.6', 'Duration': '13.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6131.5', 'Duration': '18', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6167.1', 'Duration': '20.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6218.7', 'Duration': '21.2', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6266.2', 'Duration': '14.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6383.6', 'Duration': '9.9', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6403.8', 'Duration': '15.6', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6714.6', 'Duration': '34.1', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7140.8', 'Duration': '9.9', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7230.5', 'Duration': '29.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7421.9', 'Duration': '10.9', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7622.7', 'Duration': '10.6', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7759.4', 'Duration': '15.5', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7946.5', 'Duration': '32.8', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10324', 'Duration': '17.6', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10831.3', 'Duration': '6.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11224.7', 'Duration': '25.3', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13407.3', 'Duration': '6.6', 'Notes': 'Arousal (AASM)'}, {'EventType': 'Technician Notes', 'EventC ...
#  75%|███████▌  | 1549/2056 [00:17<00:06, 72.50it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '32909.6', 'Duration': '3', 'Notes': 'Arousal (ARO Limb)'}]
#  78%|███████▊  | 1609/2056 [00:18<00:05, 88.65it/s]
# [{'EventType': 'Electrocardiogram|Electrocardiogram', 'EventConcept': 'Narrow complex tachycardia|Narrow Complex Tachycardia', 'Start': '19079.6', 'Duration': '0', 'SignalLocation': 'EKG'}]
#  79%|███████▉  | 1629/2056 [00:18<00:04, 88.03it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5811', 'Duration': '10', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5885.6', 'Duration': '14.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5914.3', 'Duration': '4.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5950.7', 'Duration': '3.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5990.4', 'Duration': '3.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6042.9', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6069.3', 'Duration': '5.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6231', 'Duration': '11.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6600.1', 'Duration': '22.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6781.8', 'Duration': '26.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6910.2', 'Duration': '7.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '6950.1', 'Duration': '24.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10014.7', 'Duration': '6.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10155.7', 'Duration': '6.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10428.1', 'Duration': '14', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10632.8', 'Duration': '32.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10678.9', 'Duration': '4.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10703', 'Duration': '5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10855.9', 'Duration': '6.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10920.8', 'Duration': '27.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11067.8', 'Duration': '4.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11149.3', 'Duration': '3.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11201.1', 'Duration': '5.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11387', 'Duration': '5.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11465.3', 'Duration': '13.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11492.4', 'Duration': '4.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11553.1', 'Duration': '5.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '11635.1', 'Duration': '9.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes ...
#  84%|████████▍ | 1722/2056 [00:19<00:03, 96.65it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '203.6', 'Duration': '6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '250.5', 'Duration': '18.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '435.7', 'Duration': '7.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '860.8', 'Duration': '9.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '1498.9', 'Duration': '7.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '1520.5', 'Duration': '6.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '1555', 'Duration': '4.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '2371', 'Duration': '13.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '2520.3', 'Duration': '9.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '2829.5', 'Duration': '9.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3533.3', 'Duration': '6.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3600.9', 'Duration': '24.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3673.6', 'Duration': '9.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3692.8', 'Duration': '10.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3778.6', 'Duration': '7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4441.4', 'Duration': '26.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4506', 'Duration': '8.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '4579.9', 'Duration': '6.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5130.4', 'Duration': '7.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5237.8', 'Duration': '5.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5460.6', 'Duration': '29', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12589.7', 'Duration': '10.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12618', 'Duration': '11.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12820.5', 'Duration': '19', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12856', 'Duration': '13.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12937.5', 'Duration': '11.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12970.1', 'Duration': '10.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13011.4', 'Duration': '6.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '13 ...
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '20749', 'Duration': '10.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '20864.8', 'Duration': '7.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '20985.3', 'Duration': '14.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '21013.8', 'Duration': '4.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '24043.3', 'Duration': '8.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25083.3', 'Duration': '26.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25200.2', 'Duration': '12.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25350.5', 'Duration': '8.5', 'Notes': 'Arousal (ARO Limb)'}]
#  91%|█████████ | 1867/2056 [00:21<00:02, 90.40it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14619.2', 'Duration': '11.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '22710.4', 'Duration': '0', 'Notes': 'Arousal (ARO Limb)'}]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5570.3', 'Duration': '4.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7609.8', 'Duration': '24.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7668.2', 'Duration': '12.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7700.5', 'Duration': '3.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '8944.4', 'Duration': '18.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9002.4', 'Duration': '3.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9021', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9065.2', 'Duration': '24.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9136.5', 'Duration': '3.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '9739.7', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '10771.2', 'Duration': '26.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12173.2', 'Duration': '10.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12206.4', 'Duration': '19.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12299.1', 'Duration': '5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12501', 'Duration': '8.5', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12536.2', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '12557.5', 'Duration': '3.7', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14838.9', 'Duration': '20.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14871.2', 'Duration': '8.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '14895.8', 'Duration': '13.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15102.1', 'Duration': '5.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15224.8', 'Duration': '7.2', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15282.5', 'Duration': '6.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15336.9', 'Duration': '4.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15376.6', 'Duration': '4.9', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '15703.2', 'Duration': '17.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '16488.2', 'Duration': '11.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '16526.9', 'Duration': '6.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Techn ...
#  99%|█████████▊| 2029/2056 [00:22<00:00, 84.99it/s]
# [{'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '3764.3', 'Duration': '8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5150.9', 'Duration': '7.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5410', 'Duration': '29.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '5550.2', 'Duration': '14.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '7608.7', 'Duration': '11.1', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '18879.2', 'Duration': '15', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '20160.4', 'Duration': '11.4', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25598.2', 'Duration': '7.3', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '25743.2', 'Duration': '12.6', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '31438.7', 'Duration': '10.8', 'Notes': 'Arousal (ARO Limb)'}, {'EventType': 'Technician Notes', 'EventConcept': 'Technician Notes', 'Start': '31700.9', 'Duration': '20.3', 'Notes': 'Arousal (ARO Limb)'}]
# 100%|██████████| 2056/2056 [00:23<00:00, 88.92it/s]
# Counter({'SpO2 desaturation|SpO2 desaturation': 413256,
#          'Hypopnea|Hypopnea': 123360,
#          'Unsure|Unsure': 84296,
#          'Obstructive apnea|Obstructive Apnea': 22616,
#          'SpO2 artifact|SpO2 artifact': 20560})
