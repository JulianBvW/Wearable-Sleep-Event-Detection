# %%
from wearsed.dataset.Recording import Recording

# %%
r1 = Recording(1738)

# %%
for ev in r1.events:
    print(ev)
# Out:
# [00:00:04, 00:00:18] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:00:32, 00:00:54] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:03:58, 00:04:08] SpO2 desaturation at SpO2 (94, base 96.0)
# [00:05:44, 00:06:01] SpO2 desaturation at SpO2 (94, base 96.0)
# [00:06:10, 00:06:50] SpO2 desaturation at SpO2 (92, base 95.0)
# [00:07:13, 00:07:37] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:07:46, 00:07:58] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:08:03, 00:08:26] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:09:05, 00:09:26] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:10:43, 00:11:02] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:13:38, 00:15:06] SpO2 desaturation at SpO2 (93, base 96.0)
# [00:16:45, 00:17:03] SpO2 desaturation at SpO2 (93, base 95.0)
# [00:17:41, 00:18:52] SpO2 desaturation at SpO2 (93, base 96.0)
# [00:19:00, 00:19:39] SpO2 desaturation at SpO2 (92, base 95.0)
# [00:19:22, 00:19:34] Obstructive apnea at Flow
# ...

# %%
for ev in r1.get_events('Central apnea'):
    print(ev)
# Out:
# [04:35:21, 04:36:10] Central apnea at Flow
# [04:36:21, 04:37:37] Central apnea at Flow
# [04:45:10, 04:45:41] Central apnea at Flow
# [04:46:47, 04:47:30] Central apnea at Flow
# [06:22:47, 06:22:57] Central apnea at Flow

# %%
r1.look_at()

# %%
r1.look_at(time='06:22:47', window_size='00:01:00')
