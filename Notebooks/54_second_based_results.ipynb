# %%
import pandas as pd

# %%
run, fold = 'attention_bottleneck', 1
data = pd.read_csv(f'../wearsed/training/attention_unet/output/{run}/f-{fold}/losses.csv')
data['f1_second_based'] = pd.read_csv('54_second_based_results.csv')
data.columns = ['train_loss', 'test_loss', 'f1 (event-based)', 'f1 (second-based)']
data.plot(grid=True, figsize=(10, 6), yticks=[i/20 for i in range(16)])
# Out:
# <Axes: >
